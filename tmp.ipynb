# %%
# from pyrage import ssh, encrypt, decrypt
import config.encryption as encrypt
from pathlib import Path
from dotenv import load_dotenv
import os

# %%
load_dotenv()
prvt_key = os.getenv("POLYMARKET_PRIVATE_KEY")

# %%
encrypt.encrypt_with_ssh(prvt_key,'secrets.age')
