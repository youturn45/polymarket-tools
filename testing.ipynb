# %%
from api.polymarket_client import PolymarketClient
from config.settings import load_config

# %%
config = load_config()
polymarket_client = PolymarketClient(config=config)

# %%
orders = polymarket_client.get_orders()
print(orders)
# Out:
# [{'id': '0x56d35da9d039ec32d1f275316dd485cda3f6d51b5fc3631ba09b198ddc22622d', 'status': 'LIVE', 'owner': 'a041ba8c-8b94-36ac-ff92-09043506d1b7', 'maker_address': '0x33B3b135660B97B4ba65DAd30bf07c7D2281D03D', 'market': '0x64f4139d9dd2c2c70baa03179822f72b4c4d5e1aa8bd687adc0c6d460df4e6b3', 'asset_id': '79929804123319538015271177319268775880766288355940731721864380027274186144296', 'side': 'BUY', 'original_size': '209', 'size_matched': '0', 'price': '0.26', 'outcome': 'Yes', 'expiration': '0', 'order_type': 'GTC', 'associate_trades': [], 'created_at': 1767765578}]

# %%
orders = polymarket_client.get_positions()
print(orders)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 orders = polymarket_client.get_positions()
#       2 print(orders)
#
# AttributeError: 'PolymarketClient' object has no attribute 'get_positions'
